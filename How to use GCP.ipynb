# %% [markdown]
# ## How to use Google Cloud Platform (GCP)
#
# ### Go to [Google Cloud Platform](https://cloud.google.com/).
#
# If you don’t have an account, you just create one. You will get $300 credit for 365 days trial. When you are registering, you need to give your credit/debit card number, however, Google won’t charge you unless you use over the credit you have.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/1.png)
#
# ### Create ‘New Project’
#
# To create new project, you can click the button next to Google Cloud Platform logo. A pop-up will be shown up and you will see ‘NEW PROJECT’ on the top right. You can click and put you project name. In my case, I already had which is called ‘MLCamp-Jeju’. I will use this project to run this guide.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/2.png)
#
# ### Set up computer engine for your project
# Go to the menu on the left side and scroll down to ‘COMPUTE’ section and click on ‘COMPUTER ENGINE’ then go to ‘VM Instance’.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/3.png)
#
# If you never create VM here before, it will show like:
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/4.png)
#
# If you want to dig deeper, just click 'Take the quickstart'. The tab will automatically show on the right side.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/5.png)
#
# After you click ‘Create’, you will see set-up page. If you took the quick start, you will see the guide step-by-step. You can select specification of Region of VM, CPU, OS, and many more based on your project. For me, I will run deep learning application. I would select as below:
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/6.png)
#
# When you are done, you just click ‘Create’ button.
#
# Yeah! We got our backend VM.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/7.png)
#
# If you want to have a frontend, you just click on ‘CREATE INSTANCE’ and follow the same steps again.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/8.png)
#
# ### Let’s try to access to our VM!
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/9.png)
#
# Basically, you can access through GCP service by clicking on ‘Open in browser window’. The command line window will be shown up.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/10.png)
#
# Now, you can put all resources and run your project as another computer 😉
#
# Even though, we can put everything on the VM, we should put on cloud service to make sure everything won’t be gone. Google Cloud Storage provides solution for everything from hosting live website to storing data.
#
# ### Let’s move to ‘Storage’ section.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/11.png)
#
# Here you will see similar as VM Instance page. To create or take the quickstart, you can try.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/12.png)
#
# You can set name, default storage class and location. I recommend choosing based on your current region. The cost might be lower and technically would be faster when you need to get from or pull in your data. When everything is good, you just click ‘Create button.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/13.png)
#
# We are ready to pull all things in storage!
#
# You can upload manually on GCP or install a Python-based tool to access Cloud Storage from the command line. This tool is called ‘gsutil’, which can be used for bucket and object management tasks, including:
# - Creating and deleting buckets.
# - Uploading, downloading, and deleting objects.
# - Listing buckets and objects.
# - Moving, copying, and renaming objects.
# - Editing object and bucket ACLs.
#
# For more information, you can visit [How-to Guides](https://cloud.google.com/storage/docs/how-to).
#
# ### Install gsutil/gcsfuse
#
# Here I will separate into two groups of users; Linux – Mac and Window.
#
# If you are Linux, Ubuntu or Mac users, you can install ‘gscfuse’. Please follow the steps on [the instruction]( https://github.com/GoogleCloudPlatform/gcsfuse/blob/master/docs/installing.md).
#
# For Window users, you have to go to [Google Cloud Website]( https://cloud.google.com/storage/docs/gsutil_install) and follow the steps in ‘Installing gsutil’. You have to download Cloud SDK installer and run .exe file.
#
# **Noted:** It works only with Python 2.7.9 or later. If you don’t have, please look carefully when you install. Don’t for get to tick ‘Bundled Python’.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/14.png)
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/15.png)
#
# When your installation is finished, you can test by opening command line and call ‘gsutil’.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/16.png)
#
# It should show information and command which we can use like the above screenshot.
#
# Now we are good to move our project to GCP. For more information about command line, please follow [gsutil quickstart](https://cloud.google.com/storage/docs/quickstart-gsutil).

# %% [markdown]
# ## Important Thing!
#
# When you finish running your project, don’t forget to stop VM. To do that, you just go to VM Instance again then click on your VM and click 'STOP'.
#
# ![](https://github.com/smiile8888/machine-learning-101/blob/master/Pictures/GCP/17.png)
#
# If you don’t stop, you credit will be gone ~ Byeee…
